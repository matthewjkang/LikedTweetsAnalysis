# %% [markdown]
# # <center>User Analysis via Twitter Likes </u></center>
# ##### <center>An Investigative Study by Kaushik G, Evan P, Matthew K, Cherrise M</center>
#
# ## I. Intro
#
# ### What kind of information can be extracted from a user's twitter likes?
#
# My name is Matthew Kang. I have had my Twitter account since January, 2011.
#
# To this day, I have made 368 tweets. But I have liked 5686 tweets.
#
# Looking through someone's likes is an intensely personal thing to do.
#
# Tweets, Retweets, and Quotes are all meant to be displayed to the public. But a user's likes are much more personal.
#
# Liking a tweet means that you approve of the message being conveyed by a tweet. Or, perhaps a tweet is liked because it is from a personal friend. Other times, likes are used in the same way that one uses a coin in a wishing well. (e.g. , "Like this tweet to find love this week")
#
# A great detail of information is conveyed through a users likes. I believe that from analyzing a users likes, you can determine ones ...
#
#     Political Allignment
#     Interests
#     Friends
#
#
# This analysis is conducted using the libraries Tweepy and Pandas. I will be using my own twitter account as data.
# ___
# <br>

# %% [markdown]
# ## II. Data Preparation
#
#
# ### Step 1 : Get a user's liked tweets
#
# In this step, I will use Tweepy to get a User's likes from the Twitter API.
#
# I will need to enter my own API Credentials, so I have imported a file called Secret.py which holds them.
#
# The end result is a CSV holding all my likes. The file name of the CSV is "[userhandle]+[unixtimestamp].csv"

# %%
import Secret   # Used to import private api credentials from config file
import tweepy   # Third party python library used to interact with twitter api
import os       # Handles creation and naming of paths and files
import time     # Used to get current unix timestamp for use in the csv filename
import csv      # Used to write the response to csv

### Instantiate tweepy authentication handler by passing in API credentials
auth = tweepy.OAuth1UserHandler(
    Secret.apikey, 
    Secret.apikeysecret, 
    Secret.accesstoken, 
    Secret.accesstokensecret)

### Instantiate tweepy API object by passing in the previously made authentication handler
api = tweepy.API(
    auth,
    wait_on_rate_limit=True
    )

### Self explanatory
myUserName = input('What is the username of the account whose liked tweets you wish to view? ')

### Create path to a directory called LIKEDTWEETS
userFolder = os.path.join(os.getcwd(),'LIKEDTWEETS')
if not os.path.exists(userFolder):
    os.makedirs(userFolder)

### Create filename for the csv that will be saved into LIKEDTWEETS
filename= myUserName +"-"+ str(time.time()).split('.')[0]+'.csv' 
fullpath = os.path.join(userFolder,filename)

### Ping the API for the user's liked tweets, parsing the json response for key info : [NAME, USERNAME, TWEET_TEXT, TIMESTAMP, FAVORITE_COUNT]
### Write each row into a csv
with open(fullpath,'w+') as liked:
    a=csv.writer(liked)
    for page in tweepy.Cursor(api.get_favorites, screen_name=myUserName,tweet_mode='extended').pages():
        for tweet in page:
            a.writerow([
                tweet._json['user']['name'],
                tweet._json['user']['screen_name'],
                tweet._json['full_text'],
                tweet.created_at,
                tweet._json['favorite_count']
                ])

# %% [markdown]
# <br>

# %% [markdown]
# ---
#
# # Step 2 : Create Pandas Dataframe
#
# I am using the csv, kangaroomatthew-1661467599.csv that I created in Step 1.

# %%
import pandas as pd
df = pd.read_csv('LIKEDTWEETS/kangaroomatthew-1661467599.csv',names=['Name','@','Tweet','Time','Likes'])
df
# Out:
#                Name             @  \
# 0     Ivan Pozderac         pozda
# 1             Sakun     sakofchit
# 2          😡fermion  angryfermion
# 3             eevee         eevee
# 4              Ryan     RyanRhyn0
# ...             ...           ...
# 2414         alyssa    alyssevans
# 2415           wint          dril
# 2416    Dong Nguyen     dongatory
# 2417   Danny DeVito   DannyDeVito
# 2418           SHAQ          SHAQ
#
#                                                   Tweet  \
# 0     @UGD_Zephyr @DennisCode Here's the whole list ...
# 1     so i made a lil #CSS library that allows you t...
# 2     what the heck?? just watched all of The Matrix...
# 3     cool i must've somehow missed that only christ...
# 4     Was out on a walk and an old lady randomly sto...
# ...                                                 ...
# 2414  the only #BlueLives that matter to me TBH http...
# 2415  imagine how fucked uop it would be to have a b...
# 2416  I am sorry 'Flappy Bird' users, 22 hours from ...
# 2417                                             gaming
# 2418  A guy just asked me if i twitter, hell yeaaaaa...
#
#                            Time   Likes
# 0     2022-08-18 09:22:36+00:00     262
# 1     2022-08-11 15:27:31+00:00    2553
# 2     2022-08-05 22:35:06+00:00    5031
# 3     2022-08-02 02:27:13+00:00    1349
# 4     2022-07-31 00:25:39+00:00       2
# ...                         ...     ...
# 2414  2016-08-12 18:15:34+00:00       7
# 2415  2014-09-20 19:06:20+00:00    2282
# 2416  2014-02-08 19:02:33+00:00  115108
# 2417  2009-10-16 20:06:37+00:00  200791
# 2418  2009-02-14 17:13:34+00:00   69816
#
# [2419 rows x 5 columns]

# %%
mostliked = dict(df['@'].value_counts())
mostliked = {k:v for (k,v) in mostliked.items() if (k,v)[1]>1}
mostliked
# Out:
# {'niyacatt': 50,
#  'alyssevans': 38,
#  'orangejellie': 36,
#  'booritney': 35,
#  'existentialkale': 30,
#  'BillRatchet': 30,
#  'ysablanch': 28,
#  'ninaxrosalie': 25,
#  'Rada_Rada__': 24,
#  'cake_hoarder': 24,
#  'gaycrimsonrain': 22,
#  'Chainbody': 22,
#  'pvato13': 17,
#  'akumar_Ftw': 15,
#  'juicykelp': 15,
#  'Sadieisonfire': 14,
#  'father': 12,
#  'stepsus69': 12,
#  'pokmon_facts': 12,
#  'stephanielzhou': 12,
#  'hiyooun': 12,
#  'BobbyKrane': 12,
#  'postedinthecrib': 11,
#  'shegonsuck': 11,
#  'guwop': 10,
#  'goodbeanalt': 10,
#  'Kaylaaway_': 10,
#  'seanslimed': 10,
#  'mejor_patricio': 9,
#  'tuIuna': 9,
#  'beanytuesday': 9,
#  'shar1qa': 8,
#  'maaddiso': 8,
#  'chanbanhi': 8,
#  'rheeeah': 8,
#  'thotfuss_': 7,
#  'mineifiwildout': 7,
#  'sweatyhairy': 7,
#  'jaboukie': 7,
#  'Public_Citizen': 6,
#  'KylePlantEmoji': 6,
#  'WTMMP': 6,
#  'bambooney': 6,
#  'superskrong': 6,
#  'heygetoverhere': 6,
#  'katanasIice': 6,
#  'johnniathan': 6,
#  'lilsasquatch66': 6,
#  'tylerthecreator': 6,
#  'iucipur': 5,
#  'quartoporto2': 5,
#  'JordanReitzes': 5,
#  'vincestaples': 5,
#  'kbnoswag': 5,
#  'UnusualVideos': 5,
#  'ipablo_m': 5,
#  'hurtdeeronline': 5,
#  'StockMKTNewz': 5,
#  'LilNasX': 5,
#  'YourAnonCentral': 4,
#  'OoCPokemon': 4,
#  'stop_sweeps_atx': 4,
#  'kognomee_': 4,
#  'lunaliband': 4,
#  'griffin_wong': 4,
#  'geethsharma': 4,
#  'HotGamerSex': 4,
#  'dxxnya': 4,
#  'BrendanDaGawd': 4,
#  'HardDriveMag': 3,
#  'NLinstad': 3,
#  'snorkreloaded': 3,
#  'prophethusband': 3,
#  'ggooooddddoogg': 3,
#  'wass6p': 3,
#  'elonmusk': 3,
#  'GroovinwithC': 3,
#  '_Sebass45_': 3,
#  'elitelife_kd': 3,
#  'bjennymontero': 3,
#  'paggytheclown': 3,
#  'peterxinping': 3,
#  'mightbecursed': 3,
#  'niallplz': 3,
#  'ericandre': 3,
#  'unusual_whales': 3,
#  'trentandrewrld': 3,
#  'benchill3r': 3,
#  'nickturani': 3,
#  'chismosavirus': 3,
#  'joeygllghr': 3,
#  'RainaAsato': 3,
#  'chaselyons': 3,
#  'allahliker': 3,
#  'brainwxrms': 3,
#  'lindseyshreds': 3,
#  'jil_slander': 3,
#  'LILBTHEBASEDGOD': 3,
#  'hojpg2': 3,
#  'TweetPotato314': 3,
#  'javeigh': 3,
#  'bobbyteriyaki': 3,
#  'akchubb': 3,
#  'yungmentoz': 3,
#  'BoyYeetsWorld': 3,
#  'Keefler_Elf': 3,
#  'masturbatelog': 3,
#  'jaketropolis': 3,
#  'kwvngkim': 2,
#  'TakeForGrantd': 2,
#  'internet_menace': 2,
#  'crocodilethumbs': 2,
#  'StockMarketalk': 2,
#  'doyalikebaileys': 2,
#  'rishipuff': 2,
#  'stststanley': 2,
#  'bocxtop': 2,
#  'RespectfulMemes': 2,
#  'jazz_inmypants': 2,
#  'Kidfears99': 2,
#  'IRLDOCTOR': 2,
#  'TeahLhompson': 2,
#  'johnistoasted': 2,
#  'beefymosquito': 2,
#  'Drewphillips__': 2,
#  'dubstep4dads': 2,
#  'realwillmeade': 2,
#  'vsmarzz': 2,
#  'ColIegeStudent': 2,
#  'haterirl': 2,
#  'halaljew': 2,
#  'lukeisamazing': 2,
#  'cordae': 2,
#  'MNateShyamalan': 2,
#  'coochiedeclined': 2,
#  'CathieDWood': 2,
#  'ItsLumberzack': 2,
#  'eggyjo': 2,
#  'Julian_Epp': 2,
#  'vinnybrack': 2,
#  'shyhungaIpha': 2,
#  'kenzie_annalee': 2,
#  'eggshellfriend': 2,
#  'dmndeyes': 2,
#  'jnudey': 2,
#  'urrrnnn': 2,
#  'Shayrowdy': 2,
#  'theSirToasty': 2,
#  'EwdatsGROSS': 2,
#  'Namastaywoke': 2,
#  'imteddybless': 2,
#  'Struggle_Tweet': 2,
#  'whosalex': 2,
#  'lunch_enjoyer': 2,
#  'fbgcon': 2,
#  'kktsune': 2,
#  'ldrinkh20': 2,
#  'RoseOfWindsong': 2,
#  'TheLastHimbo': 2,
#  'sadspeIl': 2,
#  'milkygoddess': 2,
#  'userjaymes': 2,
#  'Sebastian__Thor': 2,
#  'sandavidcito': 2,
#  'WorldWideWob': 2,
#  '97Vercetti': 2,
#  'ochotato': 2,
#  'SuicidalTommy': 2,
#  'ronnui_': 2,
#  'TheFooCommunity': 2,
#  'sydneysagehorn': 2,
#  '6figgazent': 2,
#  'kanyewest': 2,
#  'itsMalikEl': 2,
#  'custardloaf': 2,
#  'jakebrodes': 2,
#  'JessicaLynnn110': 2,
#  'JimCarrey': 2,
#  'aussiesdointhgs': 2,
#  'JamesCageWhite': 2,
#  'dsemumi': 2,
#  'djoats02': 2,
#  'markedly': 2,
#  'dog_feelings': 2,
#  'rightupyouralii': 2,
#  'The_Law_Boy': 2,
#  'ryanb______': 2,
#  'jack': 2,
#  'OutOfCMalcolm': 2,
#  'tristehomo': 2,
#  'MILFWEEED': 2,
#  'impossiblyeve': 2,
#  'bl_nca': 2,
#  'sadgirlkms': 2,
#  'OfficialRezz': 2,
#  'ZeroSuitCamus': 2,
#  'pchooo0': 2,
#  'jacobhjkim': 2,
#  'FM310DY': 2,
#  'SwiftOnSecurity': 2,
#  'carterhambley': 2,
#  'ParikPatelCFA': 2,
#  'fireh9lly': 2,
#  'cthdes': 2,
#  'Kristen_Arnett': 2,
#  'TheEpicDept': 2,
#  'mas1z1': 2,
#  'bugposting': 2,
#  'autogynefiles': 2,
#  'sh44sti': 2}

# %%
pd.set_option('display.max_colwidth', None)
df.loc[df['@']=='niyacatt']['Tweet']
# Out:
# 56                                                                                                                                                                                                                @kangaroomatthew I believe it’s squash games
# 128                                                                                                                                                                                                       my skin is so clear FOR WHAT https://t.co/TAFVJfDDkX
# 265                                                                                                                                                                  anyway all my outfits have been revolving around these two skirts https://t.co/wfgvKCm0KL
# 318                                                                                                                                                                       @kangaroomatthew anh can’t handle this and this is the curry i always make sksjdjsks
# 351                                                                                  i have played so much among us i no longer think of the work “vent” the same. whenever someone says “i was venting” i think they’re an imposter even when i’m not playing
# 416                                                                                                                                                                                even on grindr, my friends stay vigilant 💃🏻💃🏻 #ACAB https://t.co/bTh9QG3T8j
# 513                                                                                                                                                                                                                               MAY WAS THREE MONTHS AGO????
# 564                                                                                                                                                                                                                this shit was a bop https://t.co/YVaTowtk0M
# 647                                                                                                                                                                                               spent $5 on a fucking carton of EGGS https://t.co/Za6FXmE9yV
# 719                                                                                                                                                                                 both my mexican and asian side be ignorant as shit https://t.co/BKGQDzwJeu
# 736                                                                                                                                                                                                                             @kangaroomatthew just tweet IT
# 749                                                                                                                                                                                             san diego opens up a little and people act like covid is cured
# 777                                                                                                                                                                                                                                      homebodies r thriving
# 814                                                                                                                                                                      one time this korean guy told me that “no true mexican listens to bad bunny” like wat
# 848                                                                                                                                                                                             people talk shit and then it’s “____ tweets are protected” 👁👄👁
# 878                                                                                                                                                             $200 for a hug $50 a month for videos of me hitting my villagers in animal crossing with a net
# 895                                                                                                                                                                         i will never forgive the bitches at my school who supported trump, never ever ever
# 904                                                                                                                                                                                                                        i lied i can’t live like this lmfao
# 921                                     thoughtiwasimportanttosomeoneonlytofondoutthattheyjustneededmewhentheyhadnooneandnowthattheyhavefriendstheysimplybarelytalktomeeventhoughihelpedthemwhentheyneededitandalwaysdidmybestanddidabsolutelynothingwrong lol
# 924                                                                                                                                                                                                               she said fuck pisces https://t.co/Gm9j9ZtBzW
# 951                                                                                                                                                                                my time perception has been lost. is it thursday? is it june? how old am i?
# 998                                                                                                                                                 i cut off the stems bc i like to shove the strawberries in my mouth without biting https://t.co/Ou11jNcL0e
# 1043                                                                                                                                                                                                                  i do not lie LOL https://t.co/Jwj6nLKckD
# 1044                                                                                                                                                                                             this guy messaged me after 2 years bc he just got out of jail
# 1053    lying about your weight loss journey and making it seem as if you lost xx pounds in such a short time is terrifying and hurts the mental health of others! people believe they can achieve these types of transformations and are hurt when they don’t
# 1054                                                 i noticed this woman was clearly lying in her weight loss photos — using a photo from February 2019 (it’s a photo taken with me) and labeling it as August 2019, and i want to confront but i’m worried 🥴
# 1070                                                                                                                                                                                                        He got auctioned on SAD, he belongs to the streets
# 1099                                                                                                                                                                                                    My grandpa keeps saying Napoleon instead of neopolitan
# 1114                           Hated tinder bc boys would literally make anything sexual. Once I told a guy I got in a car accident and am scared of driving and he was like “guess the only thing you’ll be riding is this dick” like wtf bro I’m traumatized
# 1119                                                                                                                                                                                                             @kangaroomatthew That’s it I’m fucking ur mom
# 1120                                                                                                                                                                                                                   😳😳😳 if u insist https://t.co/heSWrC596z
# 1124                                                                                                                                                                                                Alexa play Love is Gone by Slander https://t.co/iRJEz9GpHl
# 1126                                                                                                                            why do strangers add me to their private stories... bro I do not even know who kevin nguyen is and I don’t care that he hurt u
# 1129                                                                                                                                                         I became prettier, mentally and physically. My heart still is soft, and my titties r soft too 💞💫🌸
# 1223                                                                                                                                                                                                                                   Fuck it watching yugioh
# 1260                                                                                                                                                       This guy stopped talking to me like a year ago and he just snapchatted me telling me he was in jail
# 1273                                                                                   I am DONE posting photos with men who eventually hurt me, so from now on they’ll be replaced by tuxedo mask. Tuxedo mask would never betray me. https://t.co/ixKLNayUhx
# 1274                                                                                                                                                                            Imagine being attracted to a whi—🤢🤢🤢 imagine being attracted to a white gu—🤮🤮🤮
# 1280                                                                                                                                    This girl walked in to my work, said “yeah no, it smells like fish” then walked out. Ma’am this is a sushi restaurant.
# 1285                                                                                                                                                                                                           Someone impregnate me it’s for my friend aha ha
# 1302                                                                                                                                                                                                                           Thank u https://t.co/6UUwKwI2oG
# 1329                                                                                                                                                                              Drop your top 5 emojis and see if people think you’re a sub or a dom: 😔❤️🥺🥰🤒
# 1336                                                                                                                                                                                                           stop thinking I’m submissive I will fuck ur mom
# 1352                                                                                                                                                                                                                            HAHAHH https://t.co/aXJ8YWmV3s
# 1370                                                                                                                                                                                                          The difference between 5’9 and 5’10 is deafening
# 1416                                                                                                                                                                             Just need me a man who is gonna smuggle red lobster biscuits in their pockets
# 1436                                                                                                                                                                                                 It only counts as sex if I came which means I am a virgin
# 1497                                                                                                                                                                                                                   The plushies stay on the bed during sex
# 1535                                                                                                                                                      Only social media I can post my rave outfit on so here you go my 3 followers https://t.co/3Y1G6y4sAf
# 1536                                                                                                                                                                                                                                      Men are fucking dumb
# Name: Tweet, dtype: object
