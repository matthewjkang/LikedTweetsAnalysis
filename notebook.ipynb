# %% [markdown]
# # <center> <u>User Analysis via Twitter Likes </u></center>
#
# ### What kind of information can be extracted from a user's twitter likes?
#
# My name is Matthew Kang. I have had my Twitter account since January, 2011.
#
# To this day, I have made 368 tweets. But I have liked 5686 tweets.
#
# Looking through someone's likes is an intensely personal thing to do.
#
# Tweets, Retweets, and Quotes are all meant to be displayed to the public. But a user's likes are much more intimate.
#
# Liking a tweet means that you approve of the message being conveyed by a tweet. Or, perhaps a tweet is liked because it is from a personal friend. Other times, likes are used in the same way that one uses a coin in a wishing well. (e.g. , "Like this tweet to find love this week")
#
# A great detail of information is conveyed through a users likes. I believe that through analyzing a users likes, you can determine ones ...
#
# 1. Friends
# 2. Interests
# 3. Political Opinions
#
# <br>
#
# ### Methodology and Data
#
# The data used in this study will be liked tweets from a single twitter account.
# For the sake of privacy and consent, I will be using my own twitter account, @kangaroomatthew.
#
# I am utilizing Twitter's API in order to obtain the data used in this study.
#
# Tweepy, a third party library, is used to interact with Twitter's API using Python.
#
# Pandas is used to conduct data analysis, data visualization, and dataframe creation.

# %% [markdown]
# ---
# ## <center>I. Data Preparation</center>
#
#
# ### Step 1 : Get the user's liked tweets
#
# In this step, I will use Tweepy to get a User's likes from the Twitter API.
#
# I will need to enter my own API Credentials, so I have imported a file called Secret.py which holds them.
#
# The end result is a CSV holding all my likes. The file name of the CSV is "[userhandle]+[unixtimestamp].csv"
#
# <br><br>
#
# <center><i>This code is not meant to be run. It is simply here to show the viewer how the CSV containing user likes was created.</i></center>

# %%
import Secret   # Used to import private api credentials from my Secret file. 
import tweepy   # Third party python library used to interact with twitter api
import os       # Handles creation and naming of paths and files
import time     # Used to get current unix timestamp for use in the csv filename
import csv      # Used to write the response to csv

### Instantiate tweepy authentication handler by passing in API credentials
auth = tweepy.OAuth1UserHandler(
    Secret.apikey, 
    Secret.apikeysecret, 
    Secret.accesstoken, 
    Secret.accesstokensecret)

### Instantiate tweepy API object by passing in the previously made authentication handler
api = tweepy.API(
    auth,
    wait_on_rate_limit=True
    )

if not os.path.exists('LIKEDTWEETS/kangaroomatthew-1661467599.csv'):
    ### Self explanatory
    myUserName = input('What is the username of the account whose liked tweets you wish to view? ')

    ### Create path to a directory called LIKEDTWEETS
    userFolder = os.path.join(os.getcwd(),'LIKEDTWEETS')
    if not os.path.exists(userFolder):
        os.makedirs(userFolder)

    ### Create filename for the csv that will be saved into LIKEDTWEETS
    filename= myUserName +"-"+ str(time.time()).split('.')[0]+'.csv' 
    fullpath = os.path.join(userFolder,filename)

    ### Ping the API for the user's liked tweets, parsing the json response for key info : [NAME, USERNAME, TWEET_TEXT, TIMESTAMP, FAVORITE_COUNT]
    ### Write each row into a csv
    with open(fullpath,'w+') as liked:
        a=csv.writer(liked)
        for page in tweepy.Cursor(api.get_favorites, screen_name=myUserName,tweet_mode='extended').pages():
            for tweet in page:
                a.writerow([
                    tweet._json['user']['name'],
                    tweet._json['user']['screen_name'],
                    tweet._json['full_text'],
                    tweet.created_at,
                    tweet._json['favorite_count']
                    ])

# %% [markdown]
# ### Step 2 : Create Pandas Dataframe from CSV of likes
#
# I am using the csv, kangaroomatthew-1661467599.csv that I created in Step 1.

# %%
import pandas as pd
df = pd.read_csv('LIKEDTWEETS/kangaroomatthew-1661467599.csv',names=['Name','@','Tweet','Time','Likes'])
df
# Out:
#                Name             @  \
# 0     Ivan Pozderac         pozda
# 1             Sakun     sakofchit
# 2          😡fermion  angryfermion
# 3             eevee         eevee
# 4              Ryan     RyanRhyn0
# ...             ...           ...
# 2414         alyssa    alyssevans
# 2415           wint          dril
# 2416    Dong Nguyen     dongatory
# 2417   Danny DeVito   DannyDeVito
# 2418           SHAQ          SHAQ
#
#                                                   Tweet  \
# 0     @UGD_Zephyr @DennisCode Here's the whole list ...
# 1     so i made a lil #CSS library that allows you t...
# 2     what the heck?? just watched all of The Matrix...
# 3     cool i must've somehow missed that only christ...
# 4     Was out on a walk and an old lady randomly sto...
# ...                                                 ...
# 2414  the only #BlueLives that matter to me TBH http...
# 2415  imagine how fucked uop it would be to have a b...
# 2416  I am sorry 'Flappy Bird' users, 22 hours from ...
# 2417                                             gaming
# 2418  A guy just asked me if i twitter, hell yeaaaaa...
#
#                            Time   Likes
# 0     2022-08-18 09:22:36+00:00     262
# 1     2022-08-11 15:27:31+00:00    2553
# 2     2022-08-05 22:35:06+00:00    5031
# 3     2022-08-02 02:27:13+00:00    1349
# 4     2022-07-31 00:25:39+00:00       2
# ...                         ...     ...
# 2414  2016-08-12 18:15:34+00:00       7
# 2415  2014-09-20 19:06:20+00:00    2282
# 2416  2014-02-08 19:02:33+00:00  115108
# 2417  2009-10-16 20:06:37+00:00  200791
# 2418  2009-02-14 17:13:34+00:00   69816
#
# [2419 rows x 5 columns]

# %% [markdown]
# ---
# ## <center>II. Predicting a Twitter User's Friends based on Likes</center>

# %% [markdown]
# ##### Here are the accounts whose posts the user has liked most frequently.
#
# #### <center>{<u>Key</u> = Twitter Account   :   <u>Value</u> = Number of times the user has liked a tweet from that account}<center>

# %%
mostliked = dict(df['@'].value_counts())
mostliked = {k:v for (k,v) in mostliked.items() if (k,v)[1]>1}
mostliked
# Out:
# {'niyacatt': 50,
#  'alyssevans': 38,
#  'orangejellie': 36,
#  'booritney': 35,
#  'existentialkale': 30,
#  'BillRatchet': 30,
#  'ysablanch': 28,
#  'ninaxrosalie': 25,
#  'Rada_Rada__': 24,
#  'cake_hoarder': 24,
#  'gaycrimsonrain': 22,
#  'Chainbody': 22,
#  'pvato13': 17,
#  'akumar_Ftw': 15,
#  'juicykelp': 15,
#  'Sadieisonfire': 14,
#  'father': 12,
#  'stepsus69': 12,
#  'pokmon_facts': 12,
#  'stephanielzhou': 12,
#  'hiyooun': 12,
#  'BobbyKrane': 12,
#  'postedinthecrib': 11,
#  'shegonsuck': 11,
#  'guwop': 10,
#  'goodbeanalt': 10,
#  'Kaylaaway_': 10,
#  'seanslimed': 10,
#  'mejor_patricio': 9,
#  'tuIuna': 9,
#  'beanytuesday': 9,
#  'shar1qa': 8,
#  'maaddiso': 8,
#  'chanbanhi': 8,
#  'rheeeah': 8,
#  'thotfuss_': 7,
#  'mineifiwildout': 7,
#  'sweatyhairy': 7,
#  'jaboukie': 7,
#  'Public_Citizen': 6,
#  'KylePlantEmoji': 6,
#  'WTMMP': 6,
#  'bambooney': 6,
#  'superskrong': 6,
#  'heygetoverhere': 6,
#  'katanasIice': 6,
#  'johnniathan': 6,
#  'lilsasquatch66': 6,
#  'tylerthecreator': 6,
#  'iucipur': 5,
#  'quartoporto2': 5,
#  'JordanReitzes': 5,
#  'vincestaples': 5,
#  'kbnoswag': 5,
#  'UnusualVideos': 5,
#  'ipablo_m': 5,
#  'hurtdeeronline': 5,
#  'StockMKTNewz': 5,
#  'LilNasX': 5,
#  'YourAnonCentral': 4,
#  'OoCPokemon': 4,
#  'stop_sweeps_atx': 4,
#  'kognomee_': 4,
#  'lunaliband': 4,
#  'griffin_wong': 4,
#  'geethsharma': 4,
#  'HotGamerSex': 4,
#  'dxxnya': 4,
#  'BrendanDaGawd': 4,
#  'HardDriveMag': 3,
#  'NLinstad': 3,
#  'snorkreloaded': 3,
#  'prophethusband': 3,
#  'ggooooddddoogg': 3,
#  'wass6p': 3,
#  'elonmusk': 3,
#  'GroovinwithC': 3,
#  '_Sebass45_': 3,
#  'elitelife_kd': 3,
#  'bjennymontero': 3,
#  'paggytheclown': 3,
#  'peterxinping': 3,
#  'mightbecursed': 3,
#  'niallplz': 3,
#  'ericandre': 3,
#  'unusual_whales': 3,
#  'trentandrewrld': 3,
#  'benchill3r': 3,
#  'nickturani': 3,
#  'chismosavirus': 3,
#  'joeygllghr': 3,
#  'RainaAsato': 3,
#  'chaselyons': 3,
#  'allahliker': 3,
#  'brainwxrms': 3,
#  'lindseyshreds': 3,
#  'jil_slander': 3,
#  'LILBTHEBASEDGOD': 3,
#  'hojpg2': 3,
#  'TweetPotato314': 3,
#  'javeigh': 3,
#  'bobbyteriyaki': 3,
#  'akchubb': 3,
#  'yungmentoz': 3,
#  'BoyYeetsWorld': 3,
#  'Keefler_Elf': 3,
#  'masturbatelog': 3,
#  'jaketropolis': 3,
#  'kwvngkim': 2,
#  'TakeForGrantd': 2,
#  'internet_menace': 2,
#  'crocodilethumbs': 2,
#  'StockMarketalk': 2,
#  'doyalikebaileys': 2,
#  'rishipuff': 2,
#  'stststanley': 2,
#  'bocxtop': 2,
#  'RespectfulMemes': 2,
#  'jazz_inmypants': 2,
#  'Kidfears99': 2,
#  'IRLDOCTOR': 2,
#  'TeahLhompson': 2,
#  'johnistoasted': 2,
#  'beefymosquito': 2,
#  'Drewphillips__': 2,
#  'dubstep4dads': 2,
#  'realwillmeade': 2,
#  'vsmarzz': 2,
#  'ColIegeStudent': 2,
#  'haterirl': 2,
#  'halaljew': 2,
#  'lukeisamazing': 2,
#  'cordae': 2,
#  'MNateShyamalan': 2,
#  'coochiedeclined': 2,
#  'CathieDWood': 2,
#  'ItsLumberzack': 2,
#  'eggyjo': 2,
#  'Julian_Epp': 2,
#  'vinnybrack': 2,
#  'shyhungaIpha': 2,
#  'kenzie_annalee': 2,
#  'eggshellfriend': 2,
#  'dmndeyes': 2,
#  'jnudey': 2,
#  'urrrnnn': 2,
#  'Shayrowdy': 2,
#  'theSirToasty': 2,
#  'EwdatsGROSS': 2,
#  'Namastaywoke': 2,
#  'imteddybless': 2,
#  'Struggle_Tweet': 2,
#  'whosalex': 2,
#  'lunch_enjoyer': 2,
#  'fbgcon': 2,
#  'kktsune': 2,
#  'ldrinkh20': 2,
#  'RoseOfWindsong': 2,
#  'TheLastHimbo': 2,
#  'sadspeIl': 2,
#  'milkygoddess': 2,
#  'userjaymes': 2,
#  'Sebastian__Thor': 2,
#  'sandavidcito': 2,
#  'WorldWideWob': 2,
#  '97Vercetti': 2,
#  'ochotato': 2,
#  'SuicidalTommy': 2,
#  'ronnui_': 2,
#  'TheFooCommunity': 2,
#  'sydneysagehorn': 2,
#  '6figgazent': 2,
#  'kanyewest': 2,
#  'itsMalikEl': 2,
#  'custardloaf': 2,
#  'jakebrodes': 2,
#  'JessicaLynnn110': 2,
#  'JimCarrey': 2,
#  'aussiesdointhgs': 2,
#  'JamesCageWhite': 2,
#  'dsemumi': 2,
#  'djoats02': 2,
#  'markedly': 2,
#  'dog_feelings': 2,
#  'rightupyouralii': 2,
#  'The_Law_Boy': 2,
#  'ryanb______': 2,
#  'jack': 2,
#  'OutOfCMalcolm': 2,
#  'tristehomo': 2,
#  'MILFWEEED': 2,
#  'impossiblyeve': 2,
#  'bl_nca': 2,
#  'sadgirlkms': 2,
#  'OfficialRezz': 2,
#  'ZeroSuitCamus': 2,
#  'pchooo0': 2,
#  'jacobhjkim': 2,
#  'FM310DY': 2,
#  'SwiftOnSecurity': 2,
#  'carterhambley': 2,
#  'ParikPatelCFA': 2,
#  'fireh9lly': 2,
#  'cthdes': 2,
#  'Kristen_Arnett': 2,
#  'TheEpicDept': 2,
#  'mas1z1': 2,
#  'bugposting': 2,
#  'autogynefiles': 2,
#  'sh44sti': 2}

# %% [markdown]
# ##### Here are the number of times that someone tweeted at the user, and the user liked that tweet.
#
# #### <center>{<u>Key</u> = Twitter Account   :   <u>Value</u> = Number of times that twitter account tweeted at the user, and the user liked the tweet}<center>

# %%
df[df['Tweet'].str.contains('kang')]['@'].value_counts()
# Out:
# stephanielzhou     6
# niyacatt           4
# ysablanch          3
# NLinstad           3
# pvato13            3
# hiyooun            3
# mejor_patricio     2
# booritney          2
# kognomee_          2
# Rada_Rada__        2
# jacobhjkim         1
# juicykelp          1
# akumar_Ftw         1
# Kaylaaway_         1
# orangejellie       1
# K4M1___            1
# _Sebass45_         1
# GroovinwithC       1
# Sebastian__Thor    1
# alyssevans         1
# lucasmitchell9     1
# Valarian11         1
# FM310DY            1
# ipablo_m           1
# _guop              1
# Name: @, dtype: int64

# %%
numfollowers = []
for i in mostliked:
    numfollowers.append(api.get_user(screen_name = i)._json['followers_count'])

# %%
rel = pd.DataFrame(
    {'username': mostliked.keys(),
     'followers': numfollowers,
     "# of their tweets you've liked":mostliked.values(),
    })

# %%
rel.head(50)
# Out:
#            username  followers  # of their tweets you've liked
# 0          niyacatt        119                              50
# 1        alyssevans        413                              38
# 2      orangejellie        113                              36
# 3         booritney       3558                              35
# 4   existentialkale       2646                              30
# 5       BillRatchet     450365                              30
# 6         ysablanch        408                              28
# 7      ninaxrosalie         89                              25
# 8       Rada_Rada__        123                              24
# 9      cake_hoarder     152132                              24
# 10   gaycrimsonrain        312                              22
# 11        Chainbody     109176                              22
# 12          pvato13        174                              17
# 13       akumar_Ftw        808                              15
# 14        juicykelp        232                              15
# 15    Sadieisonfire     186868                              14
# 16           father     199132                              12
# 17        stepsus69        433                              12
# 18     pokmon_facts      84490                              12
# 19   stephanielzhou         51                              12
# 20          hiyooun         17                              12
# 21       BobbyKrane        410                              12
# 22  postedinthecrib     221472                              11
# 23       shegonsuck      53104                              11
# 24            guwop      69925                              10
# 25      goodbeanalt     595856                              10
# 26       Kaylaaway_         16                              10
# 27       seanslimed      28329                              10
# 28   mejor_patricio        108                               9
# 29           tuIuna       1016                               9
# 30     beanytuesday      45494                               9
# 31          shar1qa        382                               8
# 32         maaddiso        438                               8
# 33        chanbanhi     284630                               8
# 34          rheeeah        326                               8
# 35        thotfuss_        283                               7
# 36   mineifiwildout     213958                               7
# 37      sweatyhairy      81883                               7
# 38         jaboukie     891724                               7
# 39   Public_Citizen     534372                               6
# 40   KylePlantEmoji     147511                               6
# 41            WTMMP      34192                               6
# 42        bambooney      48819                               6
# 43      superskrong      52792                               6
# 44   heygetoverhere       8071                               6
# 45      katanasIice       3058                               6
# 46      johnniathan        195                               6
# 47   lilsasquatch66     456017                               6
# 48  tylerthecreator    9623041                               6
# 49          iucipur      42689                               5

# %% [markdown]
# ### Limitations and problems encountered
#
# 1. Rate Limiting
# 2. Maximum limit of 3200 liked tweets returned.
